# %% [markdown]
# # Hypothesis_Testing_Assignment

# %% [markdown]
# ### Question-1

# %%
import numpy as np
import pandas as pd 
from scipy import stats
from scipy.stats import norm

# %%
a = pd.read_csv(r"D:\Excelr\assignments\hypothisis\Cutlets.csv")
a
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
a.drop(["Unit B"], axis= 1, inplace= True)
a
# Out:
#     Unit A
# 0   6.8090
# 1   6.4376
# 2   6.9157
# 3   7.3012
# 4   7.4488
# 5   7.3871
# 6   6.8755
# 7   7.0621
# 8   6.6840
# 9   6.8236
# 10  7.3930
# 11  7.5169
# 12  6.9246
# 13  6.9256
# 14  6.5797
# 15  6.8394
# 16  6.5970
# 17  7.2705
# 18  7.2828
# 19  7.3495
# 20  6.9438
# 21  7.1560
# 22  6.5341
# 23  7.2854
# 24  6.9952
# 25  6.8568
# 26  7.2163
# 27  6.6801
# 28  6.9431
# 29  7.0852
# 30  6.7794
# 31  7.2783
# 32  7.1561
# 33  7.3943
# 34  6.9405

# %%
b = pd.read_csv(r"D:\Excelr\assignments\hypothisis\Cutlets.csv")
b
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
b.drop(["Unit A"], axis= 1, inplace= True)
b

# %%
stats.ttest_ind(a,b)

# %% [markdown]
# ### Question-2

# %%
data = pd.read_csv(r"D:\Excelr\assignments\hypothisis\LabTAT.csv")
data

# %%
p_value= stats.f_oneway(data.iloc[:,0], data.iloc[:,1], data.iloc[:,2], data.iloc[:,3])
p_value

# %%
p_value[1]

# %% [markdown]
# ### Question-3

# %%
df2= [[50,142,131,70], [550,351,480,350]]
df2

# %%
stat, p, dof, expected = stats.chi2_contingency(df2)
print(f'P-value = {p}')
print(f"Degrees of freedom = {dof}")
print(p)

# %%
prob= 0.95

# %%
alpha = 1.0 - prob
print(f"alpha = {alpha}, p_value = {p} ")
if p<= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')

# %% [markdown]
# ### Question-4

# %%
df= [[29,33,31,20],[271,267,269,280]]
df

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2 
import numpy as np
stat, p, dof, expected = stats.chi2_contingency(df)
print('dof=%d' % dof)
print(p)

# %%
alpha = 0.05
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
